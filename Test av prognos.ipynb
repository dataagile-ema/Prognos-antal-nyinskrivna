# %%
# %load_ext autoreload
# %autoreload 2
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
from data_access import read_and_prep_data
from walkforward_test import create_walkforward_forecast_test, run_walkforward_ForecastTest, plot_results_walkforward
from Figures import delete_all_figures, save_gif

# data kommer ifrån intensivvårdsregistret (SIR) https://portal.icuregswe.org/utdata/sv/report/demo.vtfstart?filter=f1c6d908-257f-424b-b6f2-822221495c93
df_to_20211226 = read_and_prep_data('Data/tidsserie_SIR1.csv') 
df_to_20170208 = read_and_prep_data('Data/tidsserie_SIR2.csv')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
delete_all_figures()
tests = create_walkforward_forecast_test(pd.Timestamp('2016-10-08'), df_to_20170208, 15, 8, "Antal nyinskrivna")
result_model, result_naive = run_walkforward_ForecastTest(tests)
save_gif()
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-a1010e31a701> in <module>
#       1 delete_all_figures()
#       2 tests = create_walkforward_forecast_test(pd.Timestamp('2016-10-08'), df_to_20170208, 15, 8, "Antal nyinskrivna")
# ----> 3 result_model, result_naive = run_walkforward_ForecastTest(tests)
#       4 save_gif()
#
# d:\Users\nemanuel\OneDrive - Capgemini\Documents\GitHub\Prognos-antal-nyinskrivna\walkforward_test.py in run_walkforward_ForecastTest(tests_list)
#      26     Returns: list of ErrorMetrics objects
#      27     """
# ---> 28     results_model = [run_ForecastTest(tests_list[i], False) for i in range(len(tests_list))]
#      29     results_naive = [run_ForecastTest(tests_list[i], True) for i in range(len(tests_list))]
#      30
#
# d:\Users\nemanuel\OneDrive - Capgemini\Documents\GitHub\Prognos-antal-nyinskrivna\walkforward_test.py in <listcomp>(.0)
#      26     Returns: list of ErrorMetrics objects
#      27     """
# ---> 28     results_model = [run_ForecastTest(tests_list[i], False) for i in range(len(tests_list))]
#      29     results_naive = [run_ForecastTest(tests_list[i], True) for i in range(len(tests_list))]
#      30
#
# d:\Users\nemanuel\OneDrive - Capgemini\Documents\GitHub\Prognos-antal-nyinskrivna\forecast_test.py in run_ForecastTest(test, naive)
#     164     """
#     165     if naive == False:
# --> 166         forecast_results = make_model_forecast(test)
#     167
#     168     else:
#
# d:\Users\nemanuel\OneDrive - Capgemini\Documents\GitHub\Prognos-antal-nyinskrivna\forecast_test.py in make_model_forecast(test)
#     116     future = model.make_future_dataframe(periods=test.periods)
#     117     # Make predictions
# --> 118     df_forecast = model.predict(future)
#     119
#     120     # cut df_forecast to only contain data from start_of_prediction_period
#
# ~\Miniconda3\envs\mcd_am\lib\site-packages\fbprophet\forecaster.py in predict(self, df)
#    1202         seasonal_components = self.predict_seasonal_components(df)
#    1203         if self.uncertainty_samples:
# -> 1204             intervals = self.predict_uncertainty(df)
#    1205         else:
#    1206             intervals = None
#
# ~\Miniconda3\envs\mcd_am\lib\site-packages\fbprophet\forecaster.py in predict_uncertainty(self, df)
#    1433         Dataframe with uncertainty intervals.
#    1434         """
# -> 1435         sim_values = self.sample_posterior_predictive(df)
#    1436
#    1437         lower_p = 100 * (1.0 - self.interval_width) / 2
#
# ~\Miniconda3\envs\mcd_am\lib\site-packages\fbprophet\forecaster.py in sample_posterior_predictive(self, df)
#    1386         for i in range(n_iterations):
#    1387             for _j in range(samp_per_iter):
# -> 1388                 sim = self.sample_model(
#    1389                     df=df,
#    1390                     seasonal_features=seasonal_features,
#
# ~\Miniconda3\envs\mcd_am\lib\site-packages\fbprophet\forecaster.py in sample_model(self, df, seasonal_features, iteration, s_a, s_m)
#    1462         Dataframe with trend and yhat, each like df['t'].
#    1463         """
# -> 1464         trend = self.sample_predictive_trend(df, iteration)
#    1465
#    1466         beta = self.params['beta'][iteration]
#
# ~\Miniconda3\envs\mcd_am\lib\site-packages\fbprophet\forecaster.py in sample_predictive_trend(self, df, iteration)
#    1520
#    1521         if self.growth == 'linear':
# -> 1522             trend = self.piecewise_linear(t, deltas, k, m, changepoint_ts)
#    1523         elif self.growth == 'logistic':
#    1524             cap = df['cap_scaled']
#
# ~\Miniconda3\envs\mcd_am\lib\site-packages\fbprophet\forecaster.py in piecewise_linear(t, deltas, k, m, changepoint_ts)
#    1240         # Get cumulative slope and intercept at each t
#    1241         k_t = k * np.ones_like(t)
# -> 1242         m_t = m * np.ones_like(t)
#    1243         for s, t_s in enumerate(changepoint_ts):
#    1244             indx = t >= t_s
#
# KeyboardInterrupt:

# %%
plot_results_walkforward(result_model, result_naive)
# Out:
# Mean MAE for model: 9.011
# Mean MAE for naive: 24.222
# Medel RMSE modell: 10.458
# Medel RMSE naive: 25.616
# Medelvärde alla residualer modell: 7.636
# Medelvärde alla residualer  naive: 6.000
