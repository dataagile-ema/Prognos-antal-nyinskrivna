# %%
# %load_ext autoreload
# %autoreload 2
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
from prognos_antal_nyinskrivna import read_and_prep_data
from prognos_antal_nyinskrivna import create_ForecastTest
from prognos_antal_nyinskrivna import run_ForecastTest

from walkforward_test import create_walkforward_forecast_test, run_walkforward_ForecastTest, calc_mean_MEA, calc_mean_RMSE, plot_results_walkforward

# data kommer ifrån intensivvårdsregistret (SIR) https://portal.icuregswe.org/utdata/sv/report/demo.vtfstart?filter=f1c6d908-257f-424b-b6f2-822221495c93
df_to_20211226 = read_and_prep_data('Data/tidsserie_SIR1.csv') 
df_to_20170208 = read_and_prep_data('Data/tidsserie_SIR2.csv')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
tests = create_walkforward_forecast_test(pd.Timestamp('2016-01-11'), df_to_20170208, 15, 5)
result_model, result_naive = run_walkforward_ForecastTest(tests)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# period of df_naive_forecast: 2016-01-11 to 2016-01-25
# period of df_train: 2014-12-02 to 2016-01-10
# period of df: 2014-12-02 to 2017-02-08
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# period of df_naive_forecast: 2016-01-26 to 2016-02-09
# period of df_train: 2014-12-02 to 2016-01-25
# period of df: 2014-12-02 to 2017-02-08
# ...

# %%
plot_results_walkforward(result_model, result_naive)
# Out:
# Mean MAE for model: 8.5
# Mean MAE for naive: 16.6
# Medel RMSE fel modell: 10.7
# Medel RMSE fel naive: 19.6
